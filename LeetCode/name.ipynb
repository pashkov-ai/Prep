# %% [markdown]
# esc - command mode
# enter - cell mode
#
# COMMAND
# b - append cell
# dd - deletes cell
# alt arrow - moves cell
# ctrl x - cuts cell
#
#
# CELL
# ctrl x - cut line
# ctrl d - duplicaste line

# %%
b
